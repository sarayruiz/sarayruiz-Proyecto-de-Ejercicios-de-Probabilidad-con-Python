# %% [markdown]
# # Probability exercises

# %% [markdown]
# ## Exercise 1
#
# Two dices are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7.  A simulation is a repetition of the same experiment multiple times to observe its behavior:
#
# - Run the experiment 1000 times (roll 2 dice 1000 times, and sum the number of both dices).
# - Keep track of the number of times that the sum was either greater than 7 or an even number.
# - Divide the number from step 2 by the number of iterations (1000).

# %%
import random
iteraciones = 1000
contador = 0

for i in range(iteraciones):
  d1 = random.randint(1, 6)
  d2 = random.randint(1, 6)
  s = d1 + d2

  if s % 2 == 0 or s > 7: 
    contador += 1

probabilidad = contador / iteraciones

print(f"La probabilidad  es {probabilidad*100}%")
# Out:
# La probabilidad  es 67.4%

# %% [markdown]
# ## Exercise 2
#
# A box contains 10 white balls, 20 red balls and 30 green balls. If we take 5 balls from the box with replacement (we take the ball, observe what color it is and put it back into the box). We want to know the probability of:
#
# 1. Take 3 white and 2 red.
# 2. All are the same color.
#
# Run the experiment 1000 times and calculate the above probabilities.

# %%
ball_box = {}

# Create the box of balls
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"



intentos = 1000

primer_caso = 0
segundo_caso = 0

for i in range(intentos):
    bolas = []
    for k in range(5):
        bola = random.choice(list(ball_box.values()))
        bolas.append(bola)

    if bolas.count("White") == 3 and bolas.count("Red") == 2:
        primer_caso += 1

    if bolas.count(bolas[0]) == 5:
        segundo_caso += 1

probabilidad_1 = primer_caso / intentos
probabilidad_2 = segundo_caso / intentos 


print(f"La probabilidad de sacar 3 bolas blancas y 2 rojas es {probabilidad_1*100}%")
print(f"La probabilidad de sacar todas las bolas del mismo color es {probabilidad_2*100}%")
# Out:
# La probabilidad de sacar 3 bolas blancas y 2 rojas es 0.4%
# La probabilidad de sacar todas las bolas del mismo color es 3.6999999999999997%
