# %% [markdown]
# # Probability exercises

# %% [markdown]
# ## Exercise 1
#
# Two dices are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7.  A simulation is a repetition of the same experiment multiple times to observe its behavior:
#
# - Run the experiment 1000 times (roll 2 dice 1000 times, and sum the number of both dices).
# - Keep track of the number of times that the sum was either greater than 7 or an even number.
# - Divide the number from step 2 by the number of iterations (1000).

# %%
# TODO

import numpy as np
import random

simulaciones = 1000
contador = 0

for i in range(simulaciones):
   
   dado1 = random.randint(1, 6)
   dado2 = random.randint(1, 6)
   suma = dado1 + dado2
   
   if (suma > 7) or (suma % 2 == 0):
     contador += 1

probabilidad = contador / simulaciones

print(f"La probabilidad estimada de que la puntuación total sea par o mayor que 7 es: {np.round(probabilidad * 100, 2)} %")
# Out:
# La probabilidad estimada de que la puntuación total sea par o mayor que 7 es: 68.1 %

# %% [markdown]
# ## Exercise 2
#
# A box contains 10 white balls, 20 red balls and 30 green balls. If we take 5 balls from the box with replacement (we take the ball, observe what color it is and put it back into the box). We want to know the probability of:
#
# 1. Take 3 white and 2 red.
# 2. All are the same color.
#
# Run the experiment 1000 times and calculate the above probabilities.

# %%
import numpy as np 
import random

ball_box = {}

# Create the box of balls
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

print(ball_box)
            
# TODO

# Función para realizar una extracción de la caja
def draw_balls(ball_box, num_draws):
    return [ball_box[random.randint(0, 59)] for n in range(num_draws)]

# Contadores para los eventos
event_3w_2r = 0
event_same_color = 0

# Simular el experimento 1000 veces
for i in range(1000):
    balls_drawn = draw_balls(ball_box, 5)
    white_balls = balls_drawn.count("White")
    red_balls = balls_drawn.count("Red")
    green_balls = balls_drawn.count("Green")
    
    # Contar si se sacan 3 bolas blancas y 2 rojas
    if white_balls == 3 and red_balls == 2:
        event_3w_2r += 1
    
    # Contar si todas las bolas son del mismo color
    if white_balls == 5 or red_balls == 5 or green_balls == 5:
        event_same_color += 1

# Calcular las probabilidades
prob_3w_2r = event_3w_2r / 1000
prob_same_color = event_same_color / 1000

print(f"Probabilidad de sacar 3 bolas blancas y 2 rojas: {np.round(prob_3w_2r * 100, 2)} %")
print(f"Probabilidad de que todas las bolas sean del mismo color: {np.round(prob_same_color*100, 2)} %")
# Out:
# {0: 'White', 1: 'White', 2: 'White', 3: 'White', 4: 'White', 5: 'White', 6: 'White', 7: 'White', 8: 'White', 9: 'White', 10: 'Red', 11: 'Red', 12: 'Red', 13: 'Red', 14: 'Red', 15: 'Red', 16: 'Red', 17: 'Red', 18: 'Red', 19: 'Red', 20: 'Red', 21: 'Red', 22: 'Red', 23: 'Red', 24: 'Red', 25: 'Red', 26: 'Red', 27: 'Red', 28: 'Red', 29: 'Red', 30: 'Green', 31: 'Green', 32: 'Green', 33: 'Green', 34: 'Green', 35: 'Green', 36: 'Green', 37: 'Green', 38: 'Green', 39: 'Green', 40: 'Green', 41: 'Green', 42: 'Green', 43: 'Green', 44: 'Green', 45: 'Green', 46: 'Green', 47: 'Green', 48: 'Green', 49: 'Green', 50: 'Green', 51: 'Green', 52: 'Green', 53: 'Green', 54: 'Green', 55: 'Green', 56: 'Green', 57: 'Green', 58: 'Green', 59: 'Green'}
# Probabilidad de sacar 3 bolas blancas y 2 rojas: 0.9 %
# Probabilidad de que todas las bolas sean del mismo color: 3.8 %
